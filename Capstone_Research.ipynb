# %% [markdown]
# <a href="https://colab.research.google.com/github/keelinarseneault/ML-Engineering/blob/main/Capstone_Research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Capstone Research Survey**

# %% [markdown]
# # Research Papers
# [ Deepfake Detection with Deep Learning: Convolutional Neural Networks versus Transformers](https://arxiv.org/pdf/2304.03698)
#
#  This 2023 paper explored the differences in performance between a few CNN architectures and transformer architectures. The results showed that CNNs did better in the same train-to-test dataset evaluations (which is more aligned with my capstone data), while transformers models performed better in the cross datasets evaluations. The struggle with choosing vision transformers, however, is the need for more data and computational resources than other options. A mapping of the way to determine if CNN or Vision Transformer is best:
#
#  ![cnn-vs-vision-transformer-a-practitioners-guide-to-v0-rg1b0uecaz0d1.png.webp](data:image/webp;base64,...)
#
#  [Deepfake Image Detection & Classification using Conv2D Neural Networks](https://ceur-ws.org/Vol-3706/Paper9.pdf)
#
#  This 2024 paper demonstrates how an improved CNN architecture (Conv2D) was used, specifically alternating with Max Pooling2D layers, to achieve an accuracy of 94.54% in deepfake image detection. The researchers used TensorFlow and Keras libraries in Python, which will be similar to my capstone. The paper also discusses the potential use of autoencoders and GANs to perform deep fake detection, so I will try out these models in future steps of exploring options for the capstone.
#
# [Deepfake detection using deep learning methods:
# A systematic and comprehensive review](https://wires.onlinelibrary.wiley.com/doi/epdf/10.1002/widm.1520)
#
# This 2022 paper provides an overview of many deep learning options for deepfake detection, but shows that most research out there today uses CNNs for deep fake detection, as seen in this graphic presented in the paper:
#
# ![Screenshot 2025-02-09 at 7.31.04 PM.png](data:image/png;base64,...)
#
#
#  This paper also dives into some examples of breakthroughs and tricks to make CNN more efficient, such as converting images with an error level analysis tool to to increase the CNN model's training efficiency - the ELA picture has less information than the original image, which can enhance efficiency.
